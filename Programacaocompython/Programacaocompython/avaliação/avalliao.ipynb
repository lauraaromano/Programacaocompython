# %% [markdown]
# 1) Crie um jogo onde o usuário deve adivinhar um número secreto entre 1 e 100. O programa deve fornecer dicas sobre se o palpite do usuário está muito alto ou muito baixo.
# O jogo deve continuar até que o usuário adivinhe corretamente ou escolha sair.

# %%
num= 50
opt= int(input("Tente adivinhar o número secreto de 1 a 100: "))

while opt!=50:

    if opt <=29:
        print("Tente digitar um número maior")
    elif opt >=70:
        print("Tente digitar um número menor")
    elif opt>29 and opt <49:
        print("Quase acertou , tente mais uma vez")


    opt= int(input("Tente adivinhar o número secreto de 1 a 100: "))


    if opt==50:
        print("Parabéns , você acertou o número.")
# Out:
# Tente adivinhar o número secreto de 1 a 100: 20
# Tente digitar um número maior
# Tente adivinhar o número secreto de 1 a 100: 12
# Tente digitar um número maior
# Tente adivinhar o número secreto de 1 a 100: 44
# Quase acertou , tente mais uma vez
# Tente adivinhar o número secreto de 1 a 100: 45
# Quase acertou , tente mais uma vez
# Tente adivinhar o número secreto de 1 a 100: 70
# Tente digitar um número menor
# Tente adivinhar o número secreto de 1 a 100: 50
# Parabéns , você acertou o número.

# %% [markdown]
# 2)Crie um programa que simula um caixa de supermercado. O usuário deve inserir o preço de cada item comprado e, após inserir todos os itens, o programa deve calcular o total da compra e aplicar um desconto de 5%, se o valor for pago a vista, caso contrário cobrança normal.
# Execute o programa até o usuário disser que deseja continuar.

# %%
total=0
cont= input("Deseja pagar? ")

while cont == "sim":
    quant = int(input("Digite a quantidade do produto escolhido: "))
    preco = float(input("Digite o preço desse produto: "))

    total += quant*preco
    print(total)

    cont= input("Deseja continuar? ")


    if cont != "sim":
        break

if cont == "não":
    print("Digite: 1- A vista  2- Parcelado ,  para decidir a forma de pagamento")
    pag= int(input("Digite sua escolha:"))

if pag==1:
    print("Você escolheu a opção a vista")

    desconto = total*0.05
    val= total-desconto
    print("O desconto foi de ", desconto,"e o valor total é de ",val, "reais")

elif pag==2:
    print("Você escolheu pagar parcelado.")
    val=total/3

    print("O valor total da compra é", total ,"você terá que pagar ",val,"por mês.")

else:
    print("Você não escoheu nenhuma opção de pagamento dada, escolha novamente")
    print("Digite: 1- A vista  2- Parcelado ,  para decidir a forma de pagamento")
    pag= int(input("Digite sua escolha:"))
# Out:
# Deseja pagar? sim
# Digite a quantidade do produto escolhido: 1212
# Digite o preço desse produto: 33
# 39996.0
# Deseja continuar? não
# Digite: 1- A vista  2- Parcelado ,  para decidir a forma de pagamento
# Digite sua escolha:2
# Você escolheu pagar parcelado.
# O valor total da compra é 39996.0 você terá que pagar  13332.0 por mês.
